# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('demo.csv')
df
# Out:
#           Date               Name Category  Amount
# 0   2023-05-29                gas   🏠 Home   120.0
# 1   2023-05-29            netflix   💫 Misc   189.0
# 2   2023-05-29            chicken   🥘 Food   160.0
# 3   2023-05-29            protien   🥘 Food   110.0
# 4   2023-05-29  full_stack_course  🛠️ Work  5999.0
# 5   2023-05-29    mobile_recharge  🛠️ Work   298.0
# 6   2023-05-29      water_bottles   🏠 Home   150.0
# 7   2023-05-29      peanut_butter   🥘 Food   459.0
# 8   2023-05-29          ice cream   🥘 Food    35.0
# 9   2023-05-29         water bill   🏠 Home   120.0
# 10  2023-05-29              games    🎉 Fun  1500.0

# %%
amount_by_category = df.groupby('Category')['Amount'].sum().reset_index().rename(columns={'Amount': 'Amount_spend'}).sort_values('Amount_spend', ascending=False)
amount_by_category
# Out:
#   Category  Amount_spend
# 3  🛠️ Work        6297.0
# 0    🎉 Fun        1500.0
# 4   🥘 Food         764.0
# 1   🏠 Home         390.0
# 2   💫 Misc         189.0

# %%
fig = plt.figure()
ax = sns.barplot(data=amount_by_category, x='Category', y='Amount_spend', color='#FF6969')

fig.set_facecolor("#A6D0DD")
ax.set_facecolor("#FFD3B0")

for p in ax.patches:
    ax.annotate(f"{p.get_height():.1f}", (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha='center', va='bottom')
# Out:
# /home/dinesh_dev/anaconda3/envs/expense_tracker_env/lib/python3.11/site-packages/IPython/core/events.py:89: UserWarning: Glyph 128736 (\N{HAMMER AND WRENCH}) missing from current font.
#   func(*args, **kwargs)
# /home/dinesh_dev/anaconda3/envs/expense_tracker_env/lib/python3.11/site-packages/IPython/core/events.py:89: UserWarning: Glyph 127881 (\N{PARTY POPPER}) missing from current font.
#   func(*args, **kwargs)
# /home/dinesh_dev/anaconda3/envs/expense_tracker_env/lib/python3.11/site-packages/IPython/core/events.py:89: UserWarning: Glyph 129368 (\N{SHALLOW PAN OF FOOD}) missing from current font.
#   func(*args, **kwargs)
# /home/dinesh_dev/anaconda3/envs/expense_tracker_env/lib/python3.11/site-packages/IPython/core/events.py:89: UserWarning: Glyph 127968 (\N{HOUSE BUILDING}) missing from current font.
#   func(*args, **kwargs)
# /home/dinesh_dev/anaconda3/envs/expense_tracker_env/lib/python3.11/site-packages/IPython/core/events.py:89: UserWarning: Glyph 128171 (\N{DIZZY SYMBOL}) missing from current font.
#   func(*args, **kwargs)
# /home/dinesh_dev/anaconda3/envs/expense_tracker_env/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128736 (\N{HAMMER AND WRENCH}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/dinesh_dev/anaconda3/envs/expense_tracker_env/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127881 (\N{PARTY POPPER}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/dinesh_dev/anaconda3/envs/expense_tracker_env/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 129368 (\N{SHALLOW PAN OF FOOD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/dinesh_dev/anaconda3/envs/expense_tracker_env/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127968 (\N{HOUSE BUILDING}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/dinesh_dev/anaconda3/envs/expense_tracker_env/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128171 (\N{DIZZY SYMBOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
